# %% [markdown]
# # About Dataset
#
# The two datasets are related to red and white variants of the Portuguese "Vinho Verde" wine. Following are the Input variables (based on physicochemical tests):
# 1. fixed acidity
# 2. volatile acidity
# 3. citric acid
# 4. residual sugar
# 5. chlorides
# 6. free sulfur dioxide
# 7. total sulfur dioxide
# 8. density
# 9. pH
# 10. sulphates
# 11. alcohol
# Output variable (based on sensory data):
# 12. quality (score between 0 and 10)
#
# [Source](https://archive.ics.uci.edu/ml/datasets/wine+quality)

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
red = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", delimiter=';')
white = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv", delimiter=';')

# %% [markdown]
# ## Finding Correlation

# %%
white.corr()["quality"][:-1].abs().sort_values(ascending = False)
# Out:
# alcohol                 0.435575
# density                 0.307123
# chlorides               0.209934
# volatile acidity        0.194723
# total sulfur dioxide    0.174737
# fixed acidity           0.113663
# pH                      0.099427
# residual sugar          0.097577
# sulphates               0.053678
# citric acid             0.009209
# free sulfur dioxide     0.008158
# Name: quality, dtype: float64

# %%
w_corr = white.corr()["quality"][:-1]
r_corr = red.corr()["quality"][:-1]

# %%
r_corr
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# Name: quality, dtype: float64

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ## Using 'fivethirtyeight' style

# %%
plt.style.use("fivethirtyeight")

fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values)
ax.barh(r_corr.index, r_corr)

plt.show()

# %% [markdown]
# Adjusting the presentation

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)

plt.show()

# %% [markdown]
# Removing labels

# %%
fig, ax = plt.subplots(figsize = (9,5))


ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])


plt.show()

# %% [markdown]
# Putting labels in the center for better presentation

# %%
l = w_corr.index
l1 = [s.title() for s in w_corr.index]

coord = [0.71,0.67,0.76, 0.67, 0.77, 0.6,0.59,0.8, 0.91, 0.77,0.82]

# %%
fig, ax = plt.subplots(figsize = (9,5))


ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1


plt.show()

# %% [markdown]
# Adding vertical lines

# %%
fig, ax = plt.subplots(figsize = (9,5))


ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
plt.show()

# %% [markdown]
# Adding horizontal lines

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.68, xmax = 0.98  )

plt.show()

# %% [markdown]
# Adding value labels

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.7,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)
ax.text(1.43,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)

plt.show()

# %% [markdown]
# Inserting horizontal line for header

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.42, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.7,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)
ax.text(1.43,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)

ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

plt.show()

# %% [markdown]
# Adding Titles

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2)
ax.barh(r_corr.index, r_corr, left = -0.1)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.42, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.7,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)
ax.text(1.43,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)

ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.3,11.3, "RED WINE",weight = "bold" )
ax.text(1.75,11.3, "WHITE WINE", weight = "bold" )


plt.show()

# %% [markdown]
# Adding source information

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2, height = 0.45)
ax.barh(r_corr.index, r_corr, left = -0.1, height = 0.45)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.42, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.7,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)
ax.text(1.43,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)

ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.3,11.3, "RED WINE",weight = "bold" )
ax.text(1.75,11.3, "WHITE WINE", weight = "bold" )

ax.text(-0.7, -2.9,"@kennyfahad" + " "*53+ "Source: University of California, Irvine",
        color = "white", backgroundcolor = "#4d4d4d", weight = "bold", size = 13)


plt.show()

# %% [markdown]
# Adding Title

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2, height = 0.45)
ax.barh(r_corr.index, r_corr, left = -0.1, height = 0.45)
ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.42, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.7,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)
ax.text(1.43,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)

ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32  )
ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98  )

ax.text(-0.3,11.3, "RED WINE",weight = "bold" )
ax.text(1.75,11.3, "WHITE WINE", weight = "bold" )

ax.text(-0.7, -2.9,"@kennyfahad" + " "*53+ "Source: University of California, Irvine",
        color = "white", backgroundcolor = "#4d4d4d", weight = "bold", size = 13)


ax.text(-0.7,13.5, "Wine Quality Strongly Correlates With Alcohol Level", size = 17, weight = "bold")
ax.text(-0.7,12.7, "Correltaion values between wine quality and wine properties")

plt.show()

# %% [markdown]
# Trying to get a custom color scheme

# %%
white_corr = w_corr>=0
red_corr = r_corr>=0

# %%
d = {True:"#33a1c9", False: "#ffae42"}

w_map = white_corr.replace(d)
r_map = red_corr.map(d)

# %%
fig, ax = plt.subplots(figsize = (9,5))

ax.barh(w_corr.index, w_corr.values, left = 2, height = 0.45, color =w_map )
ax.barh(r_corr.index, r_corr, left = -0.1, height = 0.45, color =r_map )

ax.grid(visible = False)
ax.set_xticklabels([])
ax.set_yticklabels([])

x_coord = dict(zip(l1,coord))
y_coord = -0.2

for label, x in x_coord.items():
    ax.text(x,y_coord,label)
    y_coord += 1

ax.axvline(0.5, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )
ax.axvline(1.42, c = "grey", alpha = 0.2, linewidth =1, ymax = 0.95, ymin = 0.09 )

ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32)
ax.axhline(-1, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98)

ax.text(-0.7,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)
ax.text(1.43,-1.7, "-0.5"+" "*32+"+0.5", c = "grey", alpha = 0.5)

ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.01, xmax = 0.32)
ax.axhline(11, c = "grey", alpha = 0.2, linewidth =1, xmin =0.67, xmax = 0.98)

ax.text(-0.3,11.3, "RED WINE",weight = "bold" )
ax.text(1.75,11.3, "WHITE WINE", weight = "bold")

ax.text(-0.7, -2.9,"@kennyfahad" + " "*53+ "Source: University of California, Irvine",
        color = "white", backgroundcolor = "#4d4d4d", weight = "bold", size = 13)


ax.text(-0.7,13.5, "Wine Quality Strongly Correlates With Alcohol Level", size = 17, weight = "bold")
ax.text(-0.7,12.7, "Correltaion values between wine quality and wine properties")

plt.savefig('wine.png')
plt.show()
